# %%
import pandas as pd
import numpy as np
import pickle
import glob
from functools import lru_cache
import math
import urllib.request

# %%
base_url = "https://raw.githubusercontent.com/potentialreviewer/Optimal-SNA/main/data/"

files = [
    "SemEval-2010_AKE_results.pkl",
    "NUS_AKE_results.pkl",
    "Inspec_AKE_results.pkl",
    "KDD_AKE_results.pkl",
    "WWW_AKE_results.pkl",
    "SemEval-2017_AKE_results.pkl",
    "DUC-2001_AKE_results.pkl",
    "500N-KP-Crowd_AKE_results.pkl"

]

for f in files:
    urllib.request.urlretrieve(base_url + f, f)

# %%
dfs = []

for path in glob.glob('*_AKE_results.pkl'):
    dataset_name = path.replace('_AKE_results.pkl', '')
    df = pd.read_pickle(path)
    df = df.drop(columns=['F', 'pF'])
    df = df.rename(columns={'Model': 'AKE Method', 'hF': 'hF1'})
    df['Dataset'] = dataset_name
    dfs.append(df)

AKE_dataset = pd.concat(dfs, ignore_index=True)

# %%
url = "https://raw.githubusercontent.com/potentialreviewer/Optimal-SNA/main/data/Community_Detection.pkl"
file_name = "Community_Detection.pkl"

urllib.request.urlretrieve(url, file_name)

# %%
with open("Community_Detection.pkl", "rb") as f:
    community_detection = pickle.load(f)

# %%
community_detection = community_detection.drop(columns=['Parameters', 'Isolated Nodes', 'Edge Count'])
DP = community_detection.merge(AKE_dataset, on=['Dataset', 'AKE Method'], how='left')

# %%
DP
# Out:
#             Dataset AKE Method  Zeta Edge Measure Algorithm  Modularity  \
# 0     500N-KP-Crowd         TF  0.25           CF       CNM    0.064823
# 1     500N-KP-Crowd         TF  0.25           CF   Louvain    0.055147
# 2     500N-KP-Crowd         TF  0.25           CF    Leiden    0.075047
# 3     500N-KP-Crowd         TF  0.25           CF      FLPA    0.000000
# 4     500N-KP-Crowd         TF  0.25         Dice       CNM    0.189070
# ...             ...        ...   ...          ...       ...         ...
# 3259   SemEval-2017     LMRANK  0.75      Jaccard      FLPA    0.644908
# 3260   SemEval-2017     LMRANK  0.75       Cosine       CNM    0.794301
# 3261   SemEval-2017     LMRANK  0.75       Cosine   Louvain    0.794301
# 3262   SemEval-2017     LMRANK  0.75       Cosine    Leiden    0.794301
# 3263   SemEval-2017     LMRANK  0.75       Cosine      FLPA    0.742139
#
#             RI       hF1
# 0     0.874820  0.363168
# 1     0.874820  0.363168
# 2     0.874820  0.363168
# 3     0.874820  0.363168
# 4     0.852951  0.363168
# ...        ...       ...
# 3259  0.627747  0.289670
# 3260  0.000000  0.289670
# 3261  0.000000  0.289670
# 3262  0.000000  0.289670
# 3263  0.000000  0.289670
#
# [3264 rows x 8 columns]

# %%
def compute_objectives(DP):
    DP["Objective Function"] = DP["hF1"] + DP["RI"] + DP["Modularity"]
    return DP

def dp_optimal_policy(DP, top_n=5):
    datasets = DP["Dataset"].unique()

    for dataset in datasets:
        dataset_df = DP[DP["Dataset"] == dataset].copy()
        print(f"\n===== {dataset} =====")

        # ===== Stage 3: f3* =====
        stage3_groups = dataset_df.groupby(["AKE Method", "Zeta", "Edge Measure"], sort=False)
        f3_star = {}
        for triple, group in stage3_groups:
            max_Q = group["Modularity"].max()
            best_algorithms = group[group["Modularity"] == max_Q]["Algorithm"].tolist()
            f3_star[triple] = {"max_Q": max_Q, "best_algorithms": best_algorithms, "RI": group["RI"].iloc[0]}

        # ===== Stage 2: f2* =====
        f2_star = {}
        for ake in dataset_df["AKE Method"].unique():
            ake_group = dataset_df[dataset_df["AKE Method"] == ake]
            candidates = []
            for zeta in ake_group["Zeta"].unique():
                zeta_group = ake_group[ake_group["Zeta"] == zeta]
                for edge in zeta_group["Edge Measure"].unique():
                    triple = (ake, zeta, edge)
                    stage3_information = f3_star[triple]
                    f2_value = stage3_information["RI"] + stage3_information["max_Q"]
                    candidates.append((f2_value, zeta, edge, stage3_information["best_algorithms"]))
            max_f2 = max(c[0] for c in candidates)
            f2_star[ake] = [c for c in candidates if c[0] == max_f2]

        # ===== Stage 1: f1* =====
        dp_rows = []
        for ake in dataset_df["AKE Method"].unique():
            hF1_value = dataset_df[dataset_df["AKE Method"] == ake]["hF1"].iloc[0]
            for f2_value, zeta, edge, best_algorithms in f2_star[ake]:
                total_value = hF1_value + f2_value
                for algorithm in best_algorithms:
                    dp_rows.append({
                        "AKE": ake,
                        "Zeta": zeta,
                        "Edge": edge,
                        "Algorithm": algorithm,
                        "hF1": hF1_value,
                        "RI": f3_star[(ake, zeta, edge)]["RI"],
                        "Q": f3_star[(ake, zeta, edge)]["max_Q"],
                        "Objective Function": total_value
                    })

        dp_rows_sorted = sorted(dp_rows, key=lambda x: x["Objective Function"], reverse=True)
        count = 0
        last_value = None
        for r in dp_rows_sorted:
            if count >= top_n and r["Objective Function"] != last_value:
                break
            print(f"AKE: {r['AKE']}, Zeta: {r['Zeta']}, Edge: {r['Edge']}, "
                  f"Algorithm: {r['Algorithm']}, hF1: {r['hF1']:.16f}, "
                  f"RI: {r['RI']:.16f}, Q: {r['Q']:.16f}, "
                  f"Objective Function: {r['Objective Function']:.16f}")
            last_value = r["Objective Function"]
            count += 1

# %%
DP = compute_objectives(DP)
dp_optimal_policy(DP, top_n=5)
# Out:
# ===== 500N-KP-Crowd =====
# AKE: TfIdf, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.3365800222744511, RI: 0.9965551724137929, Q: 0.5469087983804564, Objective Function: 1.8800439930687003
# AKE: PositionRank, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.2800983315961591, RI: 0.9836035398230092, Q: 0.5076657527071793, Objective Function: 1.7713676241263476
# AKE: SingleRank, Zeta: 0.25, Edge: Cosine, Algorithm: CNM, hF1: 0.2548865730269983, RI: 0.9775089108910888, Q: 0.5299562422588925, Objective Function: 1.7623517261769797
# AKE: SingleRank, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0
Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.1640020111435387, RI: 0.9759844155844160, Q: 0.5247034106046377, Objective Function: 1.6646898373325925
# AKE: TfIdf, Zeta: 0.5, Edge: Cosine, Algorithm: Louvain, hF1: 0.2066801753747238, RI: 0.9263475409836078, Q: 0.4615414160545167, Objective Function: 1.5945691324128484
#
# ===== DUC-2001 =====
# AKE: LMRANK, Zeta: 0.75, Edge: Cosine, Algorithm: CNM, hF1: 0.2400942168427161, RI: 0.9022558823529419, Q: 0.7143968396235438, Objective Function: 1.8567469388192017
# AKE: LMRANK, Zeta: 0.75, Edge: Cosine, Algorithm: Louvain, hF1: 0.2400942168427161, RI: 0.9022558823529419, Q: 0.7143968396235438, Objective Function: 1.8567469388192017
# AKE: LMRANK, Zeta: 0.75, Edge: Cosine, Algorithm: Leiden, hF1: 0.2400942168427161, RI: 0.9022558823529419, Q: 0.7143968396235438, Objective Function: 1.8567469388192017
# AKE: PositionRank, Zeta: 0.5, Edge: Cosine, Algorithm: Leiden, hF1: 0.2814006194209100, RI: 0.8900253164556966, Q: 0.6716801156748879, Objective Function: 1.8431060515514945
# AKE: TextRank1, Zeta: 0.75, Edge: Cosine, Algorithm: CNM, hF1: 0.1244855516540807, RI: 0.9923275000000005, Q: 0.7082413265235106, Objective Function: 1.8250543781775916
# AKE: TextRank1, Zeta: 0.75, Edge: Cosine, Algorithm: Louvain, hF1: 0.1244855516540807, RI: 0.9923275000000005, Q: 0.7082413265235106, Objective Function: 1.8250543781775916
#
# ===== Inspec =====
# AKE: LMRANK, Zeta: 0.5, Edge: Jaccard, Algorithm: Leiden, hF1: 0.3635761824675477, RI: 0.9929125000000001, Q: 0.6308614891128608, Objective Function: 1.9873501715804087
# AKE: SingleRank, Zeta: 0.5, Edge: Cosine, Algorithm: Leiden, hF1: 0.2872370223230907, RI: 0.9463295774647890, Q: 0.6377317934238144, Objective Function: 1.8712983932116940
# AKE: PositionRank, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.2869417972689406, RI: 0.9668242424242429, Q: 0.5991038416478569, Objective Function: 1.8528698813410405
# AKE: KPMiner, Zeta: 0.25, Edge: Dice, Algorithm: Leiden, hF1: 0.0923758192613940, RI: 0.9822274509803923, Q: 0.7034386247637752, Objective Function: 1.7780418950055614
# AKE: TfIdf, Zeta: 0.25, Edge: Cosine, Algorithm: CNM, hF1: 0.2344699480194324, RI: 0.9914727272727282, Q: 0.5179494506355191, Objective Function: 1.7438921259276796
# AKE: TfIdf, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.2344699480194324, RI: 0.9914727272727282, Q: 0.5179494506355191, Objective Function: 1.7438921259276796
#
# ===== NUS =====
# AKE: KPMiner, Zeta: 0.75, Edge: Cosine, Algorithm: CNM, hF1: 0.3413474972827923, RI: 0.9908180180180184, Q: 0.5679402201924513, Objective Function: 1.9001057354932620
# AKE: TfIdf, Zeta: 0.75, Edge: Cosine, Algorithm: CNM, hF1: 0.2579336101440217, RI: 0.9546032786885241, Q: 0.4306707663338364, Objective Function: 1.6432076551663823
# AKE: TextRank1, Zeta: 0.75, Edge: Cosine, Algorithm: Leiden, hF1: 0.0214711004687980, RI: 0.9281026548672572, Q: 0.3113151670531223, Objective Function: 1.2608889223891775
# AKE: YAKE, Zeta: 0.75, Edge: Cosine, Algorithm: Leiden, hF1: 0.2329841594751484, RI: 0.7880721311475433, Q: 0.1324935745954746, Objective Function: 1.1535498652181662
# AKE: LMRANK, Zeta: 0.5, Edge: Cosine, Algorithm: Leiden, hF1: 0.1452735566255009, RI: 0.7772349514563117, Q: 0.2045211286007427, Objective Function: 1.1270296366825554
#
# ===== SemEval-2017 =====
# AKE: KeyBERT, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.4847867231667780, RI: 0.9490909090909094, Q: 0.6355160414129046, Objective Function: 2.0693936736705920
# AKE: MDERANK, Zeta: 0.25, Edge: Cosine, Algorithm: Louvain, hF1: 0.4634835056493697, RI: 0.9937741176470591, Q: 0.5849236997721992, Objective Function: 2.0421813230686281
# AKE: MDERANK, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.4634835056493697, RI: 0.9937741176470591, Q: 0.5849236997721992, Objective Function: 2.0421813230686281
# AKE: SingleRank, Zeta: 0.75, Edge: Cosine, Algorithm: Louvain, hF1: 0.4258406976133312, RI: 0.9880336842105267, Q: 0.5020503637865698, Objective Function: 1.9159247456104276
# AKE: PositionRank, Zeta: 0.25, Edge: Cosine, Algorithm: Leiden, hF1: 0.3986521135426235, RI: 0.9951739130434788, Q: 0.4640298419971364, Objective Function: 1.8578558685832387

# %%
DP
# Out:
#             Dataset AKE Method  Zeta Edge Measure Algorithm  Modularity  \
# 0     500N-KP-Crowd         TF  0.25           CF       CNM    0.064823
# 1     500N-KP-Crowd         TF  0.25           CF   Louvain    0.055147
# 2     500N-KP-Crowd         TF  0.25           CF    Leiden    0.075047
# 3     500N-KP-Crowd         TF  0.25           CF      FLPA    0.000000
# 4     500N-KP-Crowd         TF  0.25         Dice       CNM    0.189070
# ...             ...        ...   ...          ...       ...         ...
# 3259   SemEval-2017     LMRANK  0.75      Jaccard      FLPA    0.644908
# 3260   SemEval-2017     LMRANK  0.75       Cosine       CNM    0.794301
# 3261   SemEval-2017     LMRANK  0.75       Cosine   Louvain    0.794301
# 3262   SemEval-2017     LMRANK  0.75       Cosine    Leiden    0.794301
# 3263   SemEval-2017     LMRANK  0.75       Cosine      FLPA    0.742139
#
#             RI       hF1  Objective Function
# 0     0.874820  0.363168            1.302810
# 1     0.874820  0.363168            1.293134
# 2     0.874820  0.363168            1.313035
# 3     0.874820  0.363168            1.237988
# 4     0.852951  0.363168            1.405189
# ...        ...       ...                 ...
# 3259  0.627747  0.289670            1.562325
# 3260  0.000000  0.289670            1.083971
# 3261  0.000000  0.289670            1.083971
# 3262  0.000000  0.289670            1.083971
# 3263  0.000000  0.289670            1.031809
#
# [3264 rows x 9 columns]
